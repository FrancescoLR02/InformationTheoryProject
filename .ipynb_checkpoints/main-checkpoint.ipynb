# %% [markdown]
# # Libraries

# %%
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd
import os 
import random
from tqdm import tqdm 

from VariationalModel import *

import torch
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader
from torch import nn
from torch.nn import functional as F
from typing import List
import torch
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %% [markdown]
# # Set up

# %% [markdown]
# ## Tracking activations hidden layers

# %%
activations = {} 
history_encoder = []
history_decoder = []

# %%
def get_activation(name):
    """Hook that stores the output of a layer"""
    def hook(model, input, output):
        activations[name] = output.detach()
    return hook


def setup_hooks(model):
    """Attach hooks to encoder and decoder layers (call once)"""
    activations.clear()

    for i, layer in enumerate(model.Encoder):
        layer.register_forward_hook(get_activation(f'encoder_layer_{i}'))

    for i, layer in enumerate(model.Decoder):
        layer.register_forward_hook(get_activation(f'decoder_layer_{i}'))

# %% [markdown]
# ## Mutual Info (KDE method)

# %%
def kde_entropy(data, sigma=0.1):
    if isinstance(data, torch.Tensor):
        data = data.detach().cpu().numpy()

    N, d = data.shape

    if N > 2000:
        idx = np.random.choice(N, 2000, replace=False)
        data = data[idx]

    data_sq = np.sum(data**2, axis=1, keepdims=True)
    dists_sq = data_sq + data_sq.T - 2 * np.dot(data, data.T)

    kernel = np.exp(-dists_sq / (2 * sigma**2))
    density = np.mean(kernel, axis=1)

    return -np.mean(np.log(density + 1e-10))


def get_mutual_information_kde(layer_data, target_data, sigma=0.1):
    h_layer = kde_entropy(layer_data, sigma)
    h_target = kde_entropy(target_data, sigma)

    joint = np.concatenate([layer_data, target_data], axis=1)
    h_joint = kde_entropy(joint, sigma)

    return h_layer + h_target - h_joint

# %%
def VAE_info(model, dataset, device='cpu', num_samples=1000):
    model.eval()
    model.to(device)

    loader = torch.utils.data.DataLoader(dataset, batch_size=num_samples, shuffle=True)
    inputs, _ = next(iter(loader))
    inputs = inputs.to(device)

    with torch.no_grad():
        outputs, z, mean, std = model(inputs)

    X_data = inputs.view(inputs.size(0), -1).detach().cpu().numpy()
    Z_data = z.detach().cpu().numpy()

    last_dec_idx = len(model.Decoder) - 1
    dec_last = activations[f'decoder_layer_{last_dec_idx}'].to(device)
    Recon_data = torch.sigmoid(model.finalLayer(dec_last)).detach().cpu().numpy()

    mi = {'encoder': [], 'decoder': []}

    for i in range(len(model.Encoder)):
        act = activations[f'encoder_layer_{i}'].detach().cpu().numpy()
        mi['encoder'].append((
            get_mutual_information_kde(act, X_data),
            get_mutual_information_kde(act, Z_data)
        ))

    mi['encoder'].append((
        get_mutual_information_kde(Z_data, X_data),
        get_mutual_information_kde(Z_data, Z_data)
    ))

    for i in range(len(model.Decoder)):
        act = activations[f'decoder_layer_{i}'].detach().cpu().numpy()
        mi['decoder'].append((
            get_mutual_information_kde(act, Z_data),
            get_mutual_information_kde(act, Recon_data)
        ))

    return mi

# %% [markdown]
# ## Training function VAE

# %%
def Training(model, num_epochs=10, showImage=False):
    setup_hooks(model)

    for epoch in range(num_epochs):
        model.train()
        losses = []

        for images, _ in tqdm(trainDataloader, desc=f"Epoch {epoch+1}/{num_epochs}"):
            images = images.to(device)

            outputs, z, mean, std = model(images)
            targets = images.view(images.size(0), -1)

            loss = loss_fn(outputs, targets)

            optim.zero_grad()
            loss.backward()
            optim.step()

            losses.append(loss.detach().cpu().numpy())

        print(f"Epoch {epoch+1}: computing mutual information")

        res = VAE_info(model, testDataset, device=device)
        history_encoder.append(res['encoder'])
        history_decoder.append(res['decoder'])

        avg_loss = np.mean(losses)
        print(f"TRAIN — Epoch {epoch+1}/{num_epochs} — loss: {avg_loss:.4f}")

        if showImage:
            model.eval()

            img = testDataset[0][0].unsqueeze(0).to(device)

            with torch.no_grad():
                recon = model(img)[0]

            fig, axs = plt.subplots(1, 2, figsize=(12, 6))

            axs[0].imshow(img.cpu().squeeze(), cmap='gist_gray')
            axs[0].set_title("Original image")

            axs[1].imshow(recon.cpu().squeeze().reshape(28, 28), cmap='gist_gray')
            axs[1].set_title(f"Reconstruction (epoch {epoch+1})")

            plt.tight_layout()
            plt.show()
            plt.close()

    return np.mean(losses)

# %% [markdown]
# # Dataset

# %%
dataDirectory = 'Dataset'


trainDataset = torchvision.datasets.MNIST(dataDirectory, train=True, download=True)
testDataset  = torchvision.datasets.MNIST(dataDirectory, train=False, download=True)

# %%
fig, axs = plt.subplots(5, 5, figsize = (10, 10))

for ax in axs.flatten():
   img, label = random.choice(trainDataset)
   ax.imshow(np.array(img), cmap = 'gist_gray')
   ax.set_title(f'Label: {label}')
   ax.set_xticks([])
   ax.set_yticks([])

# %%
#Transforms in pytorch tensors
trainTransform = transforms.Compose([transforms.ToTensor(),])
testTransform = transforms.Compose([transforms.ToTensor(),])

trainDataset.transform = trainTransform
testDataset.transform = testTransform

# %%
#Define the Dataloader
trainDataloader = DataLoader(trainDataset, batch_size=256, shuffle=True)
testDataloader = DataLoader(testDataset, batch_size=256, shuffle=False)

batch_data, batch_labels = next(iter(trainDataloader))
print(f"TRAIN BATCH SHAPE")
print(f"\t Data: {batch_data.shape}")
print(f"\t Labels: {batch_labels.shape}")

batch_data, batch_labels = next(iter(testDataloader))
print(f"TEST BATCH SHAPE")
print(f"\t Data: {batch_data.shape}")
print(f"\t Labels: {batch_labels.shape}")
# Out:
# TRAIN BATCH SHAPE
# 	 Data: torch.Size([256, 1, 28, 28])
# 	 Labels: torch.Size([256])
# TEST BATCH SHAPE
# 	 Data: torch.Size([256, 1, 28, 28])
# 	 Labels: torch.Size([256])

# %% [markdown]
# # VAE model

# %% [markdown]
# ## Set up model

# %%
model = VariationalAutoEncoder(latentDim = 10, hiddenDim=[200, 100, 100, 100])

# %%
loss_fn = torch.nn.MSELoss()

lr = 5e-4
parameToOptimize = [
   {'params': model.parameters()}
]

optim = torch.optim.Adam(parameToOptimize, lr = lr)
if torch.backends.mps.is_available():
   device = torch.device("mps")
elif torch.cuda.is_available():
   device = torch.device("cuda")
else:
   device = torch.device("cpu")

print(f'Selected device: {device}')

model.to(device)
# Out:
# Selected device: cuda
# VariationalAutoEncoder(
#   (Encoder): Sequential(
#     (0): Sequential(
#       (0): Linear(in_features=784, out_features=200, bias=True)
#       (1): ReLU()
#     )
#     (1): Sequential(
#       (0): Linear(in_features=200, out_features=100, bias=True)
#       (1): ReLU()
#     )
#     (2): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): ReLU()
#     )
#     (3): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): ReLU()
#     )
#   )
#   (EncoderMu): Linear(in_features=100, out_features=10, bias=True)
#   (EncoderSigma): Linear(in_features=100, out_features=10, bias=True)
#   (Decoder): Sequential(
#     (0): Sequential(
#       (0): Linear(in_features=10, out_features=100, bias=True)
#       (1): ReLU()
#     )
#     (1): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): ReLU()
#     )
#     (2): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): ReLU()
#     )
#     (3): Sequential(
#       (0): Linear(in_features=100, out_features=200, bias=True)
#       (1): ReLU()
#     )
#   )
#   (finalLayer): Linear(in_features=200, out_features=784, bias=True)
# )

# %% [markdown]
# ## Training Model

# %%
final_loss = Training(model, num_epochs=100, showImage=False)
# Out:
# Epoch 1/100: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:04<00:00, 49.51it/s]
# Epoch 1: computing mutual information
# TRAIN — Epoch 1/100 — loss: 0.0833
# Epoch 2/100: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:04<00:00, 58.15it/s]
# Epoch 2: computing mutual information
# TRAIN — Epoch 2/100 — loss: 0.0547
# Epoch 3/100: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 64.80it/s]
# Epoch 3: computing mutual information
# TRAIN — Epoch 3/100 — loss: 0.0458
# Epoch 4/100: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 62.29it/s]
# Epoch 4: computing mutual information
# TRAIN — Epoch 4/100 — loss: 0.0402
# Epoch 5/100: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 59.84it/s]
# Epoch 5: computing mutual information
# TRAIN — Epoch 5/100 — loss: 0.0354
# Epoch 6/100: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 68.38it/s]
# Epoch 6: computing mutual information
# TRAIN — Epoch 6/100 — loss: 0.0327
# Epoch 7/100: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 72.43it/s]
# Epoch 7: computing mutual information
# TRAIN — Epoch 7/100 — loss: 0.0307
# Epoch 8/100: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 72.55it/s]
# Epoch 8: computing mutual information
# TRAIN — Epoch 8/100 — loss: 0.0293
# Epoch 9/100: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 72.82it/s]
# Epoch 9: computing mutual information
# TRAIN — Epoch 9/100 — loss: 0.0284
# Epoch 10/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 72.86it/s]
# Epoch 10: computing mutual information
# TRAIN — Epoch 10/100 — loss: 0.0278
# Epoch 11/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 71.14it/s]
# Epoch 11: computing mutual information
# TRAIN — Epoch 11/100 — loss: 0.0272
# Epoch 12/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 72.41it/s]
# Epoch 12: computing mutual information
# TRAIN — Epoch 12/100 — loss: 0.0266
# Epoch 13/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 70.83it/s]
# Epoch 13: computing mutual information
# TRAIN — Epoch 13/100 — loss: 0.0261
# Epoch 14/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 71.70it/s]
# Epoch 14: computing mutual information
# TRAIN — Epoch 14/100 — loss: 0.0256
# Epoch 15/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 70.73it/s]
# Epoch 15: computing mutual information
# TRAIN — Epoch 15/100 — loss: 0.0250
# Epoch 16/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 70.01it/s]
# Epoch 16: computing mutual information
# TRAIN — Epoch 16/100 — loss: 0.0244
# Epoch 17/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 69.25it/s]
# Epoch 17: computing mutual information
# TRAIN — Epoch 17/100 — loss: 0.0239
# Epoch 18/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 69.74it/s]
# Epoch 18: computing mutual information
# TRAIN — Epoch 18/100 — loss: 0.0234
# Epoch 19/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 69.12it/s]
# Epoch 19: computing mutual information
# TRAIN — Epoch 19/100 — loss: 0.0230
# Epoch 20/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 68.21it/s]
# Epoch 20: computing mutual information
# TRAIN — Epoch 20/100 — loss: 0.0227
# Epoch 21/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 69.67it/s]
# Epoch 21: computing mutual information
# TRAIN — Epoch 21/100 — loss: 0.0224
# Epoch 22/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 70.47it/s]
# Epoch 22: computing mutual information
# TRAIN — Epoch 22/100 — loss: 0.0221
# Epoch 23/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 72.18it/s]
# Epoch 23: computing mutual information
# TRAIN — Epoch 23/100 — loss: 0.0218
# Epoch 24/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 69.51it/s]
# Epoch 24: computing mutual information
# TRAIN — Epoch 24/100 — loss: 0.0216
# Epoch 25/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 70.16it/s]
# Epoch 25: computing mutual information
# TRAIN — Epoch 25/100 — loss: 0.0214
# Epoch 26/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 69.96it/s]
# Epoch 26: computing mutual information
# TRAIN — Epoch 26/100 — loss: 0.0212
# Epoch 27/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 62.62it/s]
# Epoch 27: computing mutual information
# TRAIN — Epoch 27/100 — loss: 0.0210
# Epoch 28/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 70.15it/s]
# Epoch 28: computing mutual information
# TRAIN — Epoch 28/100 — loss: 0.0208
# Epoch 29/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 70.36it/s]
# Epoch 29: computing mutual information
# TRAIN — Epoch 29/100 — loss: 0.0207
# Epoch 30/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 71.09it/s]
# Epoch 30: computing mutual information
# TRAIN — Epoch 30/100 — loss: 0.0205
# Epoch 31/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 70.28it/s]
# Epoch 31: computing mutual information
# TRAIN — Epoch 31/100 — loss: 0.0203
# Epoch 32/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 70.12it/s]
# Epoch 32: computing mutual information
# TRAIN — Epoch 32/100 — loss: 0.0202
# Epoch 33/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 72.29it/s]
# Epoch 33: computing mutual information
# TRAIN — Epoch 33/100 — loss: 0.0199
# Epoch 34/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 71.29it/s]
# Epoch 34: computing mutual information
# TRAIN — Epoch 34/100 — loss: 0.0197
# Epoch 35/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 72.39it/s]
# Epoch 35: computing mutual information
# TRAIN — Epoch 35/100 — loss: 0.0196
# Epoch 36/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 71.31it/s]
# Epoch 36: computing mutual information
# TRAIN — Epoch 36/100 — loss: 0.0194
# Epoch 37/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 71.25it/s]
# Epoch 37: computing mutual information
# TRAIN — Epoch 37/100 — loss: 0.0192
# Epoch 38/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 68.86it/s]
# Epoch 38: computing mutual information
# TRAIN — Epoch 38/100 — loss: 0.0190
# Epoch 39/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 69.48it/s]
# Epoch 39: computing mutual information
# TRAIN — Epoch 39/100 — loss: 0.0189
# Epoch 40/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 70.02it/s]
# Epoch 40: computing mutual information
# TRAIN — Epoch 40/100 — loss: 0.0187
# Epoch 41/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 69.10it/s]
# Epoch 41: computing mutual information
# TRAIN — Epoch 41/100 — loss: 0.0186
# Epoch 42/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 69.60it/s]
# Epoch 42: computing mutual information
# TRAIN — Epoch 42/100 — loss: 0.0184
# Epoch 43/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 72.48it/s]
# Epoch 43: computing mutual information
# TRAIN — Epoch 43/100 — loss: 0.0183
# Epoch 44/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 69.53it/s]
# Epoch 44: computing mutual information
# TRAIN — Epoch 44/100 — loss: 0.0182
# Epoch 45/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 70.33it/s]
# Epoch 45: computing mutual information
# TRAIN — Epoch 45/100 — loss: 0.0181
# Epoch 46/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 71.34it/s]
# Epoch 46: computing mutual information
# TRAIN — Epoch 46/100 — loss: 0.0180
# Epoch 47/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 70.87it/s]
# Epoch 47: computing mutual information
# TRAIN — Epoch 47/100 — loss: 0.0179
# Epoch 48/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 72.34it/s]
# Epoch 48: computing mutual information
# TRAIN — Epoch 48/100 — loss: 0.0178
# Epoch 49/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 70.15it/s]
# Epoch 49: computing mutual information
# TRAIN — Epoch 49/100 — loss: 0.0177
# Epoch 50/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 69.64it/s]
# Epoch 50: computing mutual information
# TRAIN — Epoch 50/100 — loss: 0.0176
# Epoch 51/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 69.55it/s]
# Epoch 51: computing mutual information
# TRAIN — Epoch 51/100 — loss: 0.0175
# Epoch 52/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 70.70it/s]
# Epoch 52: computing mutual information
# TRAIN — Epoch 52/100 — loss: 0.0175
# Epoch 53/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 70.28it/s]
# Epoch 53: computing mutual information
# TRAIN — Epoch 53/100 — loss: 0.0174
# Epoch 54/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 66.79it/s]
# Epoch 54: computing mutual information
# TRAIN — Epoch 54/100 — loss: 0.0173
# Epoch 55/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 71.35it/s]
# Epoch 55: computing mutual information
# TRAIN — Epoch 55/100 — loss: 0.0172
# Epoch 56/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 70.06it/s]
# Epoch 56: computing mutual information
# TRAIN — Epoch 56/100 — loss: 0.0171
# Epoch 57/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 71.88it/s]
# Epoch 57: computing mutual information
# TRAIN — Epoch 57/100 — loss: 0.0171
# Epoch 58/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 70.93it/s]
# Epoch 58: computing mutual information
# TRAIN — Epoch 58/100 — loss: 0.0170
# Epoch 59/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 71.49it/s]
# Epoch 59: computing mutual information
# TRAIN — Epoch 59/100 — loss: 0.0169
# Epoch 60/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 70.28it/s]
# Epoch 60: computing mutual information
# TRAIN — Epoch 60/100 — loss: 0.0169
# Epoch 61/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 70.89it/s]
# Epoch 61: computing mutual information
# TRAIN — Epoch 61/100 — loss: 0.0168
# Epoch 62/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 70.69it/s]
# Epoch 62: computing mutual information
# TRAIN — Epoch 62/100 — loss: 0.0167
# Epoch 63/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 71.67it/s]
# Epoch 63: computing mutual information
# TRAIN — Epoch 63/100 — loss: 0.0167
# Epoch 64/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 72.48it/s]
# Epoch 64: computing mutual information
# TRAIN — Epoch 64/100 — loss: 0.0166
# Epoch 65/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 70.91it/s]
# Epoch 65: computing mutual information
# TRAIN — Epoch 65/100 — loss: 0.0165
# Epoch 66/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 72.04it/s]
# Epoch 66: computing mutual information
# TRAIN — Epoch 66/100 — loss: 0.0165
# Epoch 67/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 68.78it/s]
# Epoch 67: computing mutual information
# TRAIN — Epoch 67/100 — loss: 0.0164
# Epoch 68/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 69.40it/s]
# Epoch 68: computing mutual information
# TRAIN — Epoch 68/100 — loss: 0.0163
# Epoch 69/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 69.86it/s]
# Epoch 69: computing mutual information
# TRAIN — Epoch 69/100 — loss: 0.0162
# Epoch 70/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 69.91it/s]
# Epoch 70: computing mutual information
# TRAIN — Epoch 70/100 — loss: 0.0162
# Epoch 71/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 70.82it/s]
# Epoch 71: computing mutual information
# TRAIN — Epoch 71/100 — loss: 0.0161
# Epoch 72/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 72.23it/s]
# Epoch 72: computing mutual information
# TRAIN — Epoch 72/100 — loss: 0.0159
# Epoch 73/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 72.61it/s]
# Epoch 73: computing mutual information
# TRAIN — Epoch 73/100 — loss: 0.0158
# Epoch 74/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 71.03it/s]
# Epoch 74: computing mutual information
# TRAIN — Epoch 74/100 — loss: 0.0157
# Epoch 75/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 72.65it/s]
# Epoch 75: computing mutual information
# TRAIN — Epoch 75/100 — loss: 0.0156
# Epoch 76/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 71.27it/s]
# Epoch 76: computing mutual information
# TRAIN — Epoch 76/100 — loss: 0.0154
# Epoch 77/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 70.48it/s]
# Epoch 77: computing mutual information
# TRAIN — Epoch 77/100 — loss: 0.0154
# Epoch 78/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 59.03it/s]
# Epoch 78: computing mutual information
# TRAIN — Epoch 78/100 — loss: 0.0152
# Epoch 79/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 59.75it/s]
# Epoch 79: computing mutual information
# TRAIN — Epoch 79/100 — loss: 0.0151
# Epoch 80/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:04<00:00, 53.35it/s]
# Epoch 80: computing mutual information
# TRAIN — Epoch 80/100 — loss: 0.0150
# Epoch 81/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:04<00:00, 55.24it/s]
# Epoch 81: computing mutual information
# TRAIN — Epoch 81/100 — loss: 0.0150
# Epoch 82/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 61.60it/s]
# Epoch 82: computing mutual information
# TRAIN — Epoch 82/100 — loss: 0.0148
# Epoch 83/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:04<00:00, 56.32it/s]
# Epoch 83: computing mutual information
# TRAIN — Epoch 83/100 — loss: 0.0148
# Epoch 84/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 59.97it/s]
# Epoch 84: computing mutual information
# TRAIN — Epoch 84/100 — loss: 0.0147
# Epoch 85/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:04<00:00, 58.33it/s]
# Epoch 85: computing mutual information
# TRAIN — Epoch 85/100 — loss: 0.0146
# Epoch 86/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 59.08it/s]
# Epoch 86: computing mutual information
# TRAIN — Epoch 86/100 — loss: 0.0145
# Epoch 87/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 61.16it/s]
# Epoch 87: computing mutual information
# TRAIN — Epoch 87/100 — loss: 0.0145
# Epoch 88/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 61.59it/s]
# Epoch 88: computing mutual information
# TRAIN — Epoch 88/100 — loss: 0.0144
# Epoch 89/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 62.52it/s]
# Epoch 89: computing mutual information
# TRAIN — Epoch 89/100 — loss: 0.0143
# Epoch 90/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 63.17it/s]
# Epoch 90: computing mutual information
# TRAIN — Epoch 90/100 — loss: 0.0143
# Epoch 91/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 59.54it/s]
# Epoch 91: computing mutual information
# TRAIN — Epoch 91/100 — loss: 0.0142
# Epoch 92/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:04<00:00, 57.08it/s]
# Epoch 92: computing mutual information
# TRAIN — Epoch 92/100 — loss: 0.0141
# Epoch 93/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:04<00:00, 54.63it/s]
# Epoch 93: computing mutual information
# TRAIN — Epoch 93/100 — loss: 0.0141
# Epoch 94/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:04<00:00, 53.48it/s]
# Epoch 94: computing mutual information
# TRAIN — Epoch 94/100 — loss: 0.0140
# Epoch 95/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:04<00:00, 53.72it/s]
# Epoch 95: computing mutual information
# TRAIN — Epoch 95/100 — loss: 0.0140
# Epoch 96/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:04<00:00, 55.24it/s]
# Epoch 96: computing mutual information
# TRAIN — Epoch 96/100 — loss: 0.0139
# Epoch 97/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:04<00:00, 55.73it/s]
# Epoch 97: computing mutual information
# TRAIN — Epoch 97/100 — loss: 0.0139
# Epoch 98/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:03<00:00, 58.85it/s]
# Epoch 98: computing mutual information
# TRAIN — Epoch 98/100 — loss: 0.0138
# Epoch 99/100: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:04<00:00, 55.97it/s]
# Epoch 99: computing mutual information
# TRAIN — Epoch 99/100 — loss: 0.0137
# Epoch 100/100: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 235/235 [00:04<00:00, 58.07it/s]
# Epoch 100: computing mutual information
# TRAIN — Epoch 100/100 — loss: 0.0137

# %% [markdown]
# # Results

# %% [markdown]
# ## Utilities Mutual Info

# %%
def plot_information_plane(mi_history_encoder, mi_history_decoder, title_suffix=""):
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))

    epochs = len(mi_history_encoder)
    cmap = plt.get_cmap('gnuplot')
    colors = [cmap(i) for i in np.linspace(0, 1, epochs)]

    ax = axes[0]
    n_layers = len(mi_history_encoder[0])

    for l in range(n_layers):
        x = [e[l][0] for e in mi_history_encoder]
        y = [e[l][1] for e in mi_history_encoder]
        ax.plot(x, y, color='gray', alpha=0.3)
        ax.scatter(x, y, c=colors, s=20)

    ax.set_xlabel("I(Layer; Input)")
    ax.set_ylabel("I(Layer; Latent Z)")
    ax.set_title(f"Encoder information plane {title_suffix}")

    ax = axes[1]
    n_layers = len(mi_history_decoder[0])

    for l in range(n_layers):
        x = [e[l][0] for e in mi_history_decoder]
        y = [e[l][1] for e in mi_history_decoder]
        ax.plot(x, y, color='gray', alpha=0.3)
        ax.scatter(x, y, c=colors, s=20)

    ax.set_xlabel("I(Layer; Latent Z)")
    ax.set_ylabel("I(Layer; Output)")
    ax.set_title(f"Decoder information plane {title_suffix}")

    plt.colorbar(
        plt.cm.ScalarMappable(cmap=cmap),
        ax=axes.ravel().tolist(),
        label="Training epoch"
    )

    plt.show()

# %%
plot_information_plane(history_encoder, history_decoder)
